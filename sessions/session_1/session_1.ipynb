# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/salmon/python_basics_training/session_1/data.csv")

# %%
data
# Out:
#        year                                           category  winner  \
# 0      1927                                              ACTOR   False
# 1      1927                                              ACTOR    True
# 2      1927                                            ACTRESS   False
# 3      1927                                            ACTRESS    True
# 4      1927                                            ACTRESS   False
# 5      1927                                      ART DIRECTION   False
# 6      1927                                      ART DIRECTION    True
# 7      1927                                      ART DIRECTION   False
# 8      1927                                     CINEMATOGRAPHY   False
# 9      1927                                     CINEMATOGRAPHY    True
# 10     1927                                     CINEMATOGRAPHY    True
# 11     1927                         DIRECTING (Comedy Picture)    True
# ...

# %%
data.groupby('entity').count().sort_values('winner', ascending=False)
# Out:
#                                                    year  category  winner
# entity
# Meryl Streep                                         21        21      21
# Titanic                                              14        14      14
# A Star Is Born                                       13        13      13
# Cleopatra                                            13        13      13
# Mary Poppins                                         12        12      12
# Mutiny on the Bounty                                 12        12      12
# Katharine Hepburn                                    12        12      12
# The Lord of the Rings: The Fellowship of the Ring    12        12      12
# Moulin Rouge                                         12        12      12
# Jack Nicholson                                       12        12      12
# La La Land                                           12        12      12
# Life of Pi                                           11        11      11
# ...
