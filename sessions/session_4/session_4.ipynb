# %% [markdown]
# # Python stuf: Functions

# %% [markdown]
# ### What is a function?

# %% [markdown]
# ### Anatomy of a function

# %% [markdown]
# - Taken from Duke University [here](http://people.duke.edu/~ccc14/sta-663-2018/notebooks/S02_Python_Functions_Annotated.html).

# %%
def func_name(arg1, arg2):
    """
    Args:
        arg1 (int): one integer
        arg2 (int): another integer

    Returns:
        result (int): the sum of both integers

    """
    result = arg1 + arg2

    return result

# %% [markdown]
# ### Average

# %% [markdown]
# - How would you write a function to return an average?

# %% [markdown]
# # Pandas stuff: Selecting rows and columns

# %%
import pandas as pd

# %%
# Load the station.csv file
sta = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/Sayalave/python_basics_training/master/sessions/session_2/station.csv')

# %% [markdown]
# ### Head

# %%
sta.head()
# Out:
#    station_id                       station_name      lat     long  \
# 0           2  San Jose Diridon Caltrain Station  37.3297 -121.902
# 1           3              San Jose Civic Center  37.3307 -121.889
# 2           4             Santa Clara at Almaden  37.3340 -121.895
# 3           5                   Adobe on Almaden  37.3314 -121.893
# 4           6                   San Pedro Square  37.3367 -121.894
#
#    dock_count      city installation_date  zip_code
# 0          27  San Jose        2013-08-06     95113
# 1          15  San Jose        2013-08-05     95113
# 2          11  San Jose        2013-08-06     95113
# 3          19  San Jose        2013-08-05     95113
# 4          15  San Jose        2013-08-07     95113

# %% [markdown]
# ### Tail

# %%
sta.tail()
# Out:
#     station_id                     station_name      lat     long  dock_count  \
# 65          77                Market at Sansome  37.7896 -122.401          27
# 66          80  Santa Clara County Civic Center  37.3526 -121.906          15
# 67          82        Broadway St at Battery St  37.7985 -122.401          15
# 68          83                       Mezes Park  37.4913 -122.236          15
# 69          84                      Ryland Park  37.3427 -121.896          15
#
#              city installation_date  zip_code
# 65  San Francisco        2013-08-25     94107
# 66       San Jose        2013-12-31     95113
# 67  San Francisco        2014-01-22     94107
# 68   Redwood City        2014-02-20     94063
# 69       San Jose        2014-04-09     95113

# %% [markdown]
# ### Index

# %%
sta.iloc[50:60, :]
# Out:
#     station_id                                   station_name      lat  \
# 50          62                                  2nd at Folsom  37.7853
# 51          63                                  Howard at 2nd  37.7870
# 52          64                              2nd at South Park  37.7823
# 53          65                                Townsend at 7th  37.7711
# 54          66                       South Van Ness at Market  37.7748
# 55          67                                 Market at 10th  37.7766
# 56          68  Yerba Buena Center of the Arts (3rd @ Howard)  37.7849
# 57          69        San Francisco Caltrain 2 (330 Townsend)  37.7766
# 58          70       San Francisco Caltrain (Townsend at 4th)  37.7766
# 59          71                  Powell at Post (Union Square)  37.7884
#
#        long  dock_count           city installation_date  zip_code
# 50 -122.396          19  San Francisco        2013-08-22     94107
# ...

# %%
sta.iloc[50:60, 0:2]
# Out:
#     station_id                                   station_name
# 50          62                                  2nd at Folsom
# 51          63                                  Howard at 2nd
# 52          64                              2nd at South Park
# 53          65                                Townsend at 7th
# 54          66                       South Van Ness at Market
# 55          67                                 Market at 10th
# 56          68  Yerba Buena Center of the Arts (3rd @ Howard)
# 57          69        San Francisco Caltrain 2 (330 Townsend)
# 58          70       San Francisco Caltrain (Townsend at 4th)
# 59          71                  Powell at Post (Union Square)

# %% [markdown]
# ### Columns

# %%
sta.columns
# Out:
# Index(['station_id', 'station_name', 'lat', 'long', 'dock_count', 'city',
#        'installation_date', 'zip_code'],
#       dtype='object')

# %%
sta['station_id']
# Out:
# 0      2
# 1      3
# 2      4
# 3      5
# 4      6
# 5      7
# 6      8
# 7      9
# 8     10
# 9     11
# 10    12
# 11    13
# 12    14
# 13    16
# 14    21
# 15    22
# 16    23
# 17    24
# 18    25
# 19    26
# 20    27
# 21    28
# 22    29
# 23    30
# 24    31
# 25    32
# 26    33
# 27    34
# 28    35
# 29    36
#       ..
# 40    51
# 41    39
# 42    54
# 43    55
# 44    56
# 45    57
# 46    58
# 47    59
# 48    60
# 49    61
# 50    62
# 51    63
# 52    64
# 53    65
# 54    66
# 55    67
# 56    68
# 57    69
# 58    70
# 59    71
# 60    72
# 61    73
# 62    74
# 63    75
# 64    76
# 65    77
# 66    80
# 67    82
# 68    83
# 69    84
# Name: station_id, Length: 70, dtype: int64

# %%
sta['station_name']
# Out:
# 0                 San Jose Diridon Caltrain Station
# 1                             San Jose Civic Center
# 2                            Santa Clara at Almaden
# 3                                  Adobe on Almaden
# 4                                  San Pedro Square
# 5                              Paseo de San Antonio
# 6                               San Salvador at 1st
# 7                                         Japantown
# 8                                San Jose City Hall
# 9                                       MLK Library
# 10                           SJSU 4th at San Carlos
# 11                                    St James Park
# 12                         Arena Green / SAP Center
# 13                       SJSU - San Salvador at 9th
# 14                                Franklin at Maple
# 15                    Redwood City Caltrain Station
# 16                          San Mateo County Center
# 17                      Redwood City Public Library
# ...
