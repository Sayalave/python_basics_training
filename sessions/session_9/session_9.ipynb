# %% [markdown]
# # Let's choose a project!

# %%
import pandas as pd
from sodapy import Socrata

# %% [markdown]
# ### Analyze Trump's tweets

# %%
trump = pd.read_csv("https://github.com/Sayalave/python_basics_training/blob/master/sessions/session_9/df_raw.csv?raw=true")

# %%
trump.head()
# Out:
#    contributors  coordinates                      created_at  \
# 0           NaN          NaN  Thu Nov 21 12:31:40 +0000 2019
# 1           NaN          NaN  Wed Aug 07 10:58:16 +0000 2019
# 2           NaN          NaN  Wed Aug 08 03:23:54 +0000 2018
# 3           NaN          NaN  Fri May 25 20:39:26 +0000 2018
# 4           NaN          NaN  Fri Aug 31 01:50:40 +0000 2018
#
#   display_text_range                                           entities  \
# 0           [0, 285]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1           [0, 221]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2           [0, 200]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3           [0, 275]  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4            [0, 54]  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN           53738
# ...

# %% [markdown]
# ### Analyze New York City's crashes

# %% [markdown]
# - About the data: https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95

# %%
# Get data from NYC Data API
client = Socrata("data.cityofnewyork.us", None)
results = client.get("qiz3-axqb", limit=1500000)
cars = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
cars.head()
# Out:
#   borough collision_id   contributing_factor_vehicle_1  \
# 0  QUEENS      4160839             Passing Too Closely
# 1     NaN      4155738           Following Too Closely
# 2     NaN      4162862             Passing Too Closely
# 3     NaN      4150889                     Unspecified
# 4  QUEENS      4161611  Driver Inattention/Distraction
#
#   contributing_factor_vehicle_2 contributing_factor_vehicle_3  \
# 0                   Unspecified                           NaN
# 1                   Unspecified                           NaN
# 2                   Unspecified                   Unspecified
# 3                   Unspecified                           NaN
# 4                   Unspecified                           NaN
#
#   contributing_factor_vehicle_4 contributing_factor_vehicle_5  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# ...

# %% [markdown]
# ### Analyze Yelp's data from the restaurants of your hometown!

# %% [markdown]
# - The focus of this project would be working with Yelp's API, so I'm not providing the data.
# - If you're interested in this project, you would have to start by creating a Yelp account, then creating API keys, and then we would need to figure out a plan to get the data!
